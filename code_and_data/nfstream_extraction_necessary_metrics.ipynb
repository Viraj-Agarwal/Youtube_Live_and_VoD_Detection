# %%
# !pip install nfstream

# %%
import nfstream
print(nfstream.__version__)
# Out:
# 6.5.3

# %%
from nfstream import NFStreamer, NFPlugin
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = NFStreamer(source="drive/MyDrive/Samsung_Prism/Captures/40_Captures/Keerthana_live_40/Live_1.pcap",statistical_analysis=True).to_pandas()

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#     id  expiration_id                                   src_ip  \
# 0    0              0                          192.168.196.194
# 1    1              0                          192.168.196.194
# 2    2              0                       2404:a800:6:34::10
# 3    3              0                          192.168.196.194
# 4    4              0  2401:4900:173a:6b9b:495d:6206:7941:276a
# 5    5              0  2401:4900:173a:6b9b:495d:6206:7941:276a
# 6    6              0  2401:4900:173a:6b9b:495d:6206:7941:276a
# 7    7              0  2401:4900:173a:6b9b:495d:6206:7941:276a
# 8    8              0                          192.168.196.194
# 9    9              0                          192.168.196.194
# 10  10              0                          192.168.196.194
# 11  11              0  2401:4900:173a:6b9b:495d:6206:7941:276a
# 12  12              0                          192.168.196.194
# 13  13              0                          192.168.196.194
# ...

# %%
max_packets=max(df["src2dst_packets"])

# %%
print(max_packets)
# Out:
# 1379

# %%
row_req=df.loc[df["src2dst_packets"]==max_packets]

# %%
row_req
# Out:
#    id  expiration_id              src_ip            src_mac   src_oui  \
# 2   2              0  2404:a800:6:34::10  1e:f4:b2:07:6b:e9  1e:f4:b2
#
#    src_port                                   dst_ip            dst_mac  \
# 2       443  2401:4900:173a:6b9b:495d:6206:7941:276a  18:26:49:db:21:3f
#
#     dst_oui  dst_port  protocol  ip_version  vlan_id  tunnel_id  \
# 2  18:26:49     53380        17           6        0          0
#
#    bidirectional_first_seen_ms  bidirectional_last_seen_ms  \
# 2                1678447403729               1678447429777
#
#    bidirectional_duration_ms  bidirectional_packets  bidirectional_bytes  \
# 2                      26048                   1632              1911902
#
#    src2dst_first_seen_ms  src2dst_last_seen_ms  src2dst_duration_ms  \
# 2          1678447403729         1678447429756                26027
#
#    src2dst_packets  src2dst_bytes  dst2src_first_seen_ms  \
# 2             1379        1876105          1678447403730
#
# ...

# %%
li=["src2dst_mean_piat_ms","dst2src_mean_piat_ms","src2dst_mean_ps","dst2src_mean_ps","src2dst_stddev_piat_ms","dst2src_stddev_piat_ms","src2dst_stddev_ps","dst2src_stddev_ps","src2dst_packets","dst2src_packets","src2dst_bytes","dst2src_bytes","src_port","dst_port","protocol"]
li.append("stream_type")
# col_df=pd.DataFrame([li])
# col_df.to_csv("drive/MyDrive/Samsung_Prism/dataset_collection_necessary_Parameters.csv",index=False,header=False)

# %%
result_list=[0]

# %%
row_req["stream_type"]=result_list
# Out:
# <ipython-input-3827-b0813d577d54>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_req["stream_type"]=result_list

# %%
row_req
# Out:
#    id  expiration_id              src_ip            src_mac   src_oui  \
# 2   2              0  2404:a800:6:34::10  1e:f4:b2:07:6b:e9  1e:f4:b2
#
#    src_port                                   dst_ip            dst_mac  \
# 2       443  2401:4900:173a:6b9b:495d:6206:7941:276a  18:26:49:db:21:3f
#
#     dst_oui  dst_port  protocol  ip_version  vlan_id  tunnel_id  \
# 2  18:26:49     53380        17           6        0          0
#
#    bidirectional_first_seen_ms  bidirectional_last_seen_ms  \
# 2                1678447403729               1678447429777
#
#    bidirectional_duration_ms  bidirectional_packets  bidirectional_bytes  \
# 2                      26048                   1632              1911902
#
#    src2dst_first_seen_ms  src2dst_last_seen_ms  src2dst_duration_ms  \
# 2          1678447403729         1678447429756                26027
#
#    src2dst_packets  src2dst_bytes  dst2src_first_seen_ms  \
# 2             1379        1876105          1678447403730
#
# ...

# %%
x=list(row_req["id"])

# %%
print(x)
# Out:
# [2]

# %%
print(li)
# Out:
# ['src2dst_mean_piat_ms', 'dst2src_mean_piat_ms', 'src2dst_mean_ps', 'dst2src_mean_ps', 'src2dst_stddev_piat_ms', 'dst2src_stddev_piat_ms', 'src2dst_stddev_ps', 'dst2src_stddev_ps', 'src2dst_packets', 'dst2src_packets', 'src2dst_bytes', 'dst2src_bytes', 'src_port', 'dst_port', 'protocol', 'stream_type']

# %%
para_list=[]
for i in li:
  para_list.append(row_req.loc[x[0]][i])
print(para_list)
# Out:
# [18.887518142235145, 103.36111111111116, 1360.482233502538, 141.4901185770751, 273.1385638564902, 631.2151505551763, 208.5051020643863, 206.11453921299653, 1379, 253, 1876105, 35797, 443, 53380, 17, 0]

# %%
para_df=pd.DataFrame(columns=li)

# %%
para_df
# Out:
# Empty DataFrame
# Columns: [src2dst_mean_piat_ms, dst2src_mean_piat_ms, src2dst_mean_ps, dst2src_mean_ps, src2dst_stddev_piat_ms, dst2src_stddev_piat_ms, src2dst_stddev_ps, dst2src_stddev_ps, src2dst_packets, dst2src_packets, src2dst_bytes, dst2src_bytes, src_port, dst_port, protocol, stream_type]
# Index: []

# %%
para_df.loc[0]=para_list

# %%
para_df
# Out:
#    src2dst_mean_piat_ms  dst2src_mean_piat_ms  src2dst_mean_ps  \
# 0             18.887518            103.361111      1360.482234
#
#    dst2src_mean_ps  src2dst_stddev_piat_ms  dst2src_stddev_piat_ms  \
# 0       141.490119              273.138564              631.215151
#
#    src2dst_stddev_ps  dst2src_stddev_ps  src2dst_packets  dst2src_packets  \
# 0         208.505102         206.114539           1379.0            253.0
#
#    src2dst_bytes  dst2src_bytes  src_port  dst_port  protocol  stream_type
# 0      1876105.0        35797.0     443.0   53380.0      17.0          0.0

# %%
para_df.to_csv("drive/MyDrive/Samsung_Prism/dataset_collection_necessary_Parameters.csv",mode='a', index=False, header=False)
row_req.to_csv("drive/MyDrive/Samsung_Prism/dataset_collection.csv",mode='a', index=False, header=False)
